# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
#from pathlib import Path
from core.retrieval.ingest_pipeline import IngestPipeline

# %%
pipeline = IngestPipeline(collection_name="notebook_test_chunks")

# %%
pdf_path = "../data/raw/Anatomy.pdf"
pipeline.ingest_pdf_file(pdf_path)
print("✅ Anatomy PDF ingestion completed successfully!")
print(f"✅ Total chunks stored: {pipeline.vector_store.collection.count()}")
# Out:
# 📄 Ingesting PDF: ../data/raw/Anatomy.pdf
# ✅ Added 38 chunks from: user_pdf
# ✅ Anatomy PDF ingestion completed successfully!
# ✅ Total chunks stored: 76

# %%
retrieved = pipeline.vector_store.collection.get()
print("Example chunk:")
print(retrieved["documents"][0])
print("Metadata:")
print(retrieved["metadatas"][0])
# Out:
# Example chunk:
# Anatomy Lecture Notes Section 1: Introduction to Anatomy What is Human Anatomy? Human anatomy, including histology and gross anatomy, is the study of the structures of the human body. The discipline of human anatomy involves the identification and description of the structures within the human body. What’s in a Name? Answer: Everything
# Metadata:
# {'chunk_index': 0, 'file_name': 'Anatomy.pdf', 'source': 'user_uploaded_pdf'}

# %% [markdown]
# -----

# %%
from unittest.mock import patch

# %%
fake_xml = """
<PubmedArticle><MedlineCitation><Article>
<ArticleTitle>Notebook Test Title</ArticleTitle>
<Abstract><AbstractText>Notebook Test Text</AbstractText></Abstract>
</Article></MedlineCitation></PubmedArticle>
"""

with patch("core.retrieval.document_loader.DocumentLoader.fetch_pubmed_abstract") as mk:
    mk.return_value = fake_xml
    pipeline.ingest_from_pubmed("999999")

print("✅ PubMed ingestion passed ✅")
# Out:
# 🔎 Fetching PubMed data for PMID: 999999
# ✂️ Chunking text...
# 📌 Adding 1 chunks to ChromaDB...
# ✅ Ingestion completed successfully!
# ✅ PubMed ingestion passed ✅

# %%
count = pipeline.vector_store.collection.count()
print(f"Stored chunks: {count}")
assert count > 0
# Out:
# Stored chunks: 40
